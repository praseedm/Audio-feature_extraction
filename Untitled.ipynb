# %% [markdown]
# # AUDIO : FEATURE EXTRACTION
#
# * duration : Total duration of the audio
# * IntensityMin : Minimum Intensity of the audio signal
# * intensityMax : Maximum Intensity of the audio signal
# * intensityMean : Mean Intensity of the audio signal
# * jitter : Jitter is the variation in periodicity of a signal
# * shimmer : Shimmer is used as one of the measures for the micro-instability of vocal cord vibrations.
# * speakRate : Rate of speaking
# * numPause : Number of Pauses
# * maxDurPause : Maximum Duration of Pauses
# * avgDurPause : Average Duration of Pauses
# * TotDurPause : Total Duration of Pauses
# * Engaging tone : how much is the voice engaging
# * Not Stressed : stress level from the voice

# %%
import librosa as lbr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import IPython.display as ipd
import librosa.display as aplot

# %%
a_path = './data/P1.wav'

# %%
data, sampling_rate = librosa.load(a_path)

# %%
time = np.arange(0, len(data)) / sampling_rate

# %%
round(time[-1],3)
# Out:
# 196.992

# %%
# plot audio
def plot_audio(data,sr):
    time = np.arange(0, len(data)) / sr
    fig,ax = plt.subplots()
    ax.plot(time,data)
    ax.set(xlabel = 'Time (s)', ylabel = 'Amplitude',title="human")
    #plt.xlabel('Time',fontsize=19)
    plt.show()

# %%
plot_audio(data,sampling_rate)

# %%
aplot.waveplot(data,sampling_rate)

# %%
absdata= np.absolute(data)

# %%
ipd.Audio(data=s, rate=sampling_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
no = data[0*sampling_rate : 2*sampling_rate]

# %%
no.max()
# Out:
# 0.00018424212

# %%
no.min()
# Out:
# -0.00015723196

# %%
ts = vs#no.max()+no.std()

# %%
np.where(absdata < ts)
# Out:
# (array([      0,       1,       2, ..., 4343671, 4343672, 4343673]),)

# %%
s = np.array(list(filter(lambda x:x > ts or x < -ts, data)))
s
# Out:
# array([-0.01053617, -0.01074229, -0.01194269, ...,  0.01256841,
#         0.01239309,  0.0103282 ], dtype=float32)

# %%
plot_audio(s,sampling_rate)

# %%
aplot.waveplot(s,sampling_rate)

# %%
time = np.arange(0, len(data)) / sampling_rate

# %%
plt.scatter(time,absdata)

# %%
t = []
c = sampling_rate
v = 1
for i in absdata:
    if i < 0.1:
        v =1
        c = c+1
    else:
        if ( v == 1):
            t.append(c)
        v = 0

# %%
ts
# Out:
# 0.01030359

# %%
ss = data[k[0]:k[1]]
time = np.arange(0, len(data)) / sampling_rate

# %%
plt.plot(ss,)

# %%
ipd.Audio(data=ss, rate=sampling_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(absdata)/sampling_rate
# Out:
# 196.99201814058958

# %%
k = lbr.effects.split(data,top_db=0.05,frame_length=sampling_rate*5)

# %%
k

# %%
k/sampling_rate

# %%
plot_audio(data[:sampling_rate*10],sampling_rate)
